# %%
import pandas as pd
from sqlalchemy import create_engine

username = 'user'
password = 'pass'
host = 'localhost'  
port = '5432'  
database = 'serrabits'

connection_string = f'postgresql://{username}:{password}@{host}:{port}/{database}'

engine = create_engine(connection_string)

# %%
df = pd.read_sql('SELECT * FROM "VW_GENERAL" LIMIT 1000', con=engine)

df.head()
# Out:
#      tconst   nconst   first_primaryName  birthYear  deathYear  \
# 0  10444100   239816   Michel Duchaussoy     1938.0     2012.0
# 1  10450974   442304  Christine Kaufmann     1945.0     2017.0
# 2  10450974   797140      Heinz Sielmann     1917.0     2006.0
# 3  10452858  1115476      Huguette Uguay     1927.0     2018.0
# 4  10452858   946514   Kim Yaroshevskaya     1923.0     2025.0
#
#                      primaryProfession  \
# 0  actor,miscellaneous,archive_footage
# 1   actress,soundtrack,archive_footage
# 2    director,cinematographer,producer
# 3                              actress
# 4       actress,writer,archive_footage
#
#                              knownForTitles titleType  \
# 0   tt1259014,tt0411272,tt0363532,tt0097884  tvSeries
# 1   tt0056556,tt0095801,tt0055539,tt0055962  tvSeries
# 2   tt0163638,tt0163804,tt0163671,tt0305025  tvSeries
# 3  tt0189289,tt0306376,tt0188328,tt10452858  tvSeries
# 4   tt0100453,tt0091988,tt0096516,tt0080735  tvSeries
#
#          first_primaryTitle             originalTitle  isAdult  startYear  \
# 0  Les Objets du XXe Siècle  Les Objets du XXe Siècle        0     1999.0
# 1   Kronen Könner Kavaliere   Kronen Könner Kavaliere        0     1984.0
# 2   Kronen Könner Kavaliere   Kronen Könner Kavaliere        0     1984.0
# 3                   Fafouin                   Fafouin        0     1954.0
# 4                   Fafouin                   Fafouin        0     1954.0
#
#    endYear  runtimeMinutes       genres category   job             characters
# 0   2000.0             3.0  Documentary    actor  None                   None
# 1   1987.0            25.0  Documentary     self  None                   Self
# 2   1987.0            25.0  Documentary     self  None                   Self
# 3   1955.0            30.0       Family  actress  None      La pendule Gudule
# 4   1955.0            30.0       Family  actress  None  La poupée Fanfreluche

# %%
df.value_counts('first_primaryName')
# Out:
# first_primaryName
# Julie Bennett          15
# Paul Winchell           5
# Atsuko Tanaka           5
# Arne Weise              4
# Bengt Bedrup            4
#                        ..
# Alekos Zartaloudis      1
# Aleka Stratigou         1
# Alejandro Sieveking     1
# Alan Thicke             1
# Alain Delon             1
# Name: count, Length: 782, dtype: int64
